# %%
import pandas as pd
import os
os.getcwd()
# Out:
# '/workspaces/datatalks-docker-workshop/pipeline'

# %%
os.listdir()
# Out:
# ['Dockerfile',
#  'ingest_data.py',
#  'docker-compose.yaml',
#  'uv.lock',
#  'output_10.parquet',
#  '.python-version',
#  'main.py',
#  'pyproject.toml',
#  'output_12.parquet',
#  '.ipynb_checkpoints',
#  'README.md',
#  'pipeline.py',
#  '.venv',
#  'notebook.ipynb',
#  'zone.ipynb',
#  'refer.txt',
#  'taxi_zone_lookup.csv']

# %%
# Read a sample of the data
df = pd.read_csv('taxi_zone_lookup.csv')

# %%
df

# %%
df.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df.dtypes
# Out:
# LocationID       int64
# Borough         object
# Zone            object
# service_zone    object
# dtype: object

# %%
dtype = {
    "LocationID": "Int64",
    "Borough": "string",
    "Zone": "string",
    "service_zone": "string",
    }
df = pd.read_csv(
    'taxi_zone_lookup.csv',
    dtype=dtype,
    )

# %%
df.dtypes
# Out:
# LocationID               Int64
# Borough         string[python]
# Zone            string[python]
# service_zone    string[python]
# dtype: object

# %%
df.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
# !uv add sqlalchemy
# Out:
# Resolved 120 packages in 10ms
# Audited 12 packages in 201ms

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
# !uv add psycopg2-binary
# Out:
# Resolved 120 packages in 0.62ms
# Audited 12 packages in 0.20ms

# %%
print(pd.io.sql.get_schema(df, name='zone', con=engine))
# Out:
# CREATE TABLE zone (
# 	"LocationID" BIGINT,
# 	"Borough" TEXT,
# 	"Zone" TEXT,
# 	service_zone TEXT
# )

# %%
# !uv add tqdm
# Out:
# Resolved 120 packages in 0.67ms
# Audited 12 packages in 0.21ms

# %%
from tqdm.auto import tqdm

# %%
df.to_sql(name='zone', con=engine, if_exists='append')
# Out:
# 0it [00:00, ?it/s]

# %%
df.head(0).to_sql(name='zone', con=engine, if_exists='replace')
# Out:
# 0

# %%
df.to_sql(name='zone', con=engine, if_exists='append')
# Out:
# 265
